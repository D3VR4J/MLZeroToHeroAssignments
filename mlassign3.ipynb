# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sys

# %%
df = pd.read_csv('diabetes.csv')
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# Data Visualization

# %%
x = np.linspace(70, 120, 10)
x
# Out:
# array([ 70.        ,  75.55555556,  81.11111111,  86.66666667,
#         92.22222222,  97.77777778, 103.33333333, 108.88888889,
#        114.44444444, 120.        ])

# %%
df.head(11).value_counts('BloodPressure')
# Out:
# BloodPressure
# 66    2
# 0     1
# 40    1
# 50    1
# 64    1
# 70    1
# 72    1
# 74    1
# 92    1
# 96    1
# dtype: int64

# %%
#y = df.head(10).value_counts('BloodPressure')

# %%
z = np.cos(x)
z
# Out:
# array([ 0.6333192 ,  0.98764885,  0.84174019,  0.2694951 , -0.43924767,
#        -0.92551409, -0.94301309, -0.48288153,  0.22182667,  0.81418097])

# %%
plt.plot(x,z, 'r', linewidth=4)
plt.plot(x,z, 'gX', markersize=10)
plt.title('Data Visualization')
plt.xlabel('Angle')
plt.ylabel('Sin Value')
plt.show()

# %%
# data vsualisation of diabetes data
yy = np.linspace(70, 120, 10)

# %%
sns.scatterplot(x = df['BloodPressure'], y = df['Pregnancies'], hue=df['Outcome'])
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Pregnancies'>

# %%
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
sns.pairplot(df, hue='Outcome', size=2)   #useful for small umbers of features
plt.show()

# %%
#uni variat for single feature

# %%
plt.hist(df['Pregnancies'], bins=40, rwidth=3, color='red', align='mid')
plt.title('Preganancies')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df['BMI'], orient='h', color='green')
# Out:
# <AxesSubplot:xlabel='BMI'>
