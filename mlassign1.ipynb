# %%
import numpy as np

# %%
a = np.random.randint(10,50, (5,5))
a
# Out:
# array([[28, 14, 13, 42, 36],
#        [14, 11, 17, 46, 34],
#        [19, 24, 48, 26, 35],
#        [43, 23, 20, 14, 20],
#        [34, 45, 33, 32, 24]])

# %%
## Indexing
a[(2,3), 2:] ##row and column index([(2nd row, 3rd row), all from 2 column
# Out:
# array([[48, 26, 35],
#        [20, 14, 20]])
